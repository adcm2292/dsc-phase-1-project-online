# %% [markdown]
# ## Appendix: Netflix Analysis
#
#  * Look at the content by type: Movies - TV Shows
#  * Top 6 Genres
#  * Top 6 Origin Countries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %store -r netflix_df
# %store -r netflix_cat

# %%
netflix = pd.merge(netflix_df, netflix_cat, on='title', how='inner')

# %%
netflix.info()
netflix.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12981 entries, 0 to 12980
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          12981 non-null  object
#  1   title         12981 non-null  object
#  2   country       12981 non-null  object
#  3   release_year  12981 non-null  int64
#  4   listed_in     12981 non-null  object
#  5   category      12981 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 709.9+ KB
#       type                                    title  \
# 0    Movie  Norm of the North: King Sized Adventure
# 1    Movie  Norm of the North: King Sized Adventure
# 2    Movie               Jandino: Whatever it Takes
# 3  TV Show                       Transformers Prime
# 4  TV Show         Transformers: Robots in Disguise
#
#                                     country  release_year  \
# 0  United States, India, South Korea, China          2019
# ...

# %%
type_count = netflix['type'].value_counts()
type_count
# Out:
# Movie      8946
# TV Show    4035
# Name: type, dtype: int64

# %%
type_count.plot.pie(label="Type", title="Netflix Content")
plt.show()

# %%
genres_count = netflix['category'].value_counts()
genres_count = genres_count[:5,]
plt.figure(figsize=(8,6))
sns.barplot(genres_count.index, genres_count.values, alpha=0.8)
plt.title('Top 5 Genres - Netflix', fontsize=26)
plt.ylabel('Total Movies', fontsize=16)
plt.xlabel('Genre', fontsize=16) 
plt.show()

# %%
country_count = netflix['country'].value_counts()
country_count = country_count[:5,]
plt.figure(figsize=(8,6))
sns.barplot(country_count.index, country_count.values, alpha=0.8)
plt.title('Top 5 Origin Countries - Netflix', fontsize=26)
plt.ylabel('Total Movies', fontsize=16)
plt.xlabel('Country', fontsize=16) 
plt.show()

# %% [markdown]
# ### Inferences:
#  * Netflix content is distributed at abot 70% Movies - 30% TV Shows.
#  * International Movies is one of the most popular categories.
#  * Looking at it by country, we see a clear dominance of the US in the movie industry followed by India.

# %% [markdown]
# ## Future Work
#
#
#  * It is important to note that we did not take into consideration the effect of the COVID-19 pandemic on consumer behavior and preferences.
#  * Hopefully more data on Netflix and other streaming services will become available in the near future.
#  That will allow us to measure the effect they have on distribution and how the money is made.

# %% [markdown]
# ## Recommendation
#
# * In our EDA we looked at the Genres individually, but more often than not movies fall within more than one category or genre. Having said that, some sort of combination between the genres shown in the image below will produce the best movies in terms of profitability and acceptance among consumers.
#
# * Set budget between 4 and 10 million dollars.
#
# * Important to consider opportunities of expansion to the international market.
#
# * Use the technology knowledge and tools of Microsoft (the parent company) to maximize quality of films as well as the distribution.

# %% [markdown]
# ![recommendation-2.png](attachment:recommendation-2.png)
